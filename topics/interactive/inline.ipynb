# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# This is the default and will render images as PNGs:
# %matplotlib inline

# %%
time = np.arange(50)
fig, ax = plt.subplots()
ax.plot(np.arange(50), np.sin(time / 3))
plt.show() # Plots as an image
