# %%
from pathlib import Path
drive_address = Path.cwd() / 'drive'
drive_address.is_dir()
# Out:
# False

# %%
from google.colab import drive
drive.mount(drive_address.as_posix())
print([item for item in drive_address.iterdir() if item.is_dir()])
# Out:
# Mounted at /content/drive
# [PosixPath('/content/drive/.file-revisions-by-id'), PosixPath('/content/drive/MyDrive'), PosixPath('/content/drive/.shortcut-targets-by-id'), PosixPath('/content/drive/Othercomputers'), PosixPath('/content/drive/.Trash-0')]

# %% [markdown]
# Permit this notebook to access your Google Drive files?
#
# This notebook is requesting access to your Google Drive files. Granting access to Google Drive will permit code executed in the notebook to modify files in your Google Drive. Make sure that you review the notebook code prior to allowing this access.
#
# No, thanks
# Connect to Google Drive

# %%
print([item for item in (drive_address / 'Othercomputers').iterdir() if item.is_dir()])
# Out:
# [PosixPath('/content/drive/Othercomputers/My Mac')]
