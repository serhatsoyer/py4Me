# %%
# %pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyobjc==9.0.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3

# %%
engine = pyttsx3.init()

# %%
engine.say("This is read by Apple.")

# %%
engine.runAndWait()
